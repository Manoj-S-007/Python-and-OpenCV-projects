# %% [markdown]
# <a href="https://colab.research.google.com/github/Manoj-S-007/Python-and-OpenCV-projects/blob/main/Goku_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
image = cv2.imread("/content/Goku.jpg")

# %%
h,w = image.shape[:2]
print("Height = {},Width = {}".format(h,w))
# Out:
# Height = 1680,Width = 1080

# %%
(b,g,r)= image[100,100]
print("R = {}, G = {}, B={}".format(r,g,b))
# Out:
# R = 16, G = 24, B=35

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1680 at 0x7FE14D31EEB0>
